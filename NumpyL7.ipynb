# %%
import numpy as np
import unittest

# %%
# 断言函数
# 使用 assert_almost_equal 断言近似相等
print(np.testing.assert_almost_equal(0.123456789, 0.123456780, decimal=7))
print(np.testing.assert_almost_equal(0.123, 0.124, decimal=3))
print(np.testing.assert_almost_equal(0.123456789, 0.12345678, decimal=9))
# Out:
# None
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-3c0e0f830d9f> in <module>
#       3 print(np.testing.assert_almost_equal(0.123456789, 0.123456780, decimal=7))
#       4 print(np.testing.assert_almost_equal(0.123, 0.124, decimal=3))
# ----> 5 print(np.testing.assert_almost_equal(0.123456789, 0.12345678, decimal=9))
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_almost_equal(actual, desired, decimal, err_msg, verbose)
#     595         pass
#     596     if abs(desired - actual) >= 1.5 * 10.0**(-decimal):
# --> 597         raise AssertionError(_build_err_msg())
#     598
#     599
#
# AssertionError:
# Arrays are not almost equal to 9 decimals
#  ACTUAL: 0.123456789
#  DESIRED: 0.12345678

# %%
# 近似相等
# abs(actual - expected) >= 10**-(significant - 1)
# 如果两个数字的近似程度没有达到指定的有效数字要求，
# assert_approx_equal函数将抛出异常。
print(np.testing.assert_approx_equal(0.123456789, 0.123456780,significant=8))
print(np.testing.assert_approx_equal(0.123456789, 0.123456780, significant=9))
# Out:
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-b6f0754d3bdf> in <module>
#       4 # assert_approx_equal函数将抛出异常。
#       5 print(np.testing.assert_approx_equal(0.123456789, 0.123456780,significant=8))
# ----> 6 print(np.testing.assert_approx_equal(0.123456789, 0.123456780, significant=9))
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_approx_equal(actual, desired, significant, err_msg, verbose)
#     694         pass
#     695     if np.abs(sc_desired - sc_actual) >= np.power(10., -(significant-1)):
# --> 696         raise AssertionError(msg)
#     697
#     698
#
# AssertionError:
# Items are not equal to 9 significant digits:
#  ACTUAL: 0.123456789
#  DESIRED: 0.12345678

# %%
# 数组近似相等
# |expected - actual| < 0.5 10-decimal
print( np.testing.assert_array_almost_equal([0, 0.123456789], [0, 
0.123456780], decimal=8))

print( np.testing.assert_array_almost_equal([0, 0.123456789], [0, 
0.123456780], decimal=9))
# Out:
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-3a69a52d3015> in <module>
#       4 0.123456780], decimal=8))
#       5
# ----> 6 print( np.testing.assert_array_almost_equal([0, 0.123456789], [0,
#       7 0.123456780], decimal=9))
#
#     [... skipping hidden 1 frame]
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     840                                 verbose=verbose, header=header,
#     841                                 names=('x', 'y'), precision=precision)
# --> 842             raise AssertionError(msg)
#     843     except ValueError:
#     844         import traceback
#
# AssertionError:
# Arrays are not almost equal to 9 decimals
#
# Mismatched elements: 1 / 2 (50%)
# Max absolute difference: 9.e-09
# Max relative difference: 7.29000059e-08
#  x: array([0.         , 0.123456789])
#  y: array([0.        , 0.12345678])

# %%
# 数组相等
# 比较数组也可以使用assert_allclose函数。
# 该函数有参数atol（absolute tolerance，绝对容差限）和rtol（relative tolerance，相对容差限）。
# |a - b| <= (atol + rtol * |b|)
print(np.testing.assert_allclose([0, 0.123456789, np.nan], [0, 0.123456780, 
np.nan], rtol=1e-7, atol=0))

print( np.testing.assert_array_equal([0, 0.123456789, np.nan], [0, 0.123456780, 
np.nan]))
# Out:
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-22a5ab2596c4> in <module>
#       6 np.nan], rtol=1e-7, atol=0))
#       7
# ----> 8 print( np.testing.assert_array_equal([0, 0.123456789, np.nan], [0, 0.123456780,
#       9 np.nan]))
#
#     [... skipping hidden 1 frame]
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     840                                 verbose=verbose, header=header,
#     841                                 names=('x', 'y'), precision=precision)
# --> 842             raise AssertionError(msg)
#     843     except ValueError:
#     844         import traceback
#
# AssertionError:
# Arrays are not equal
#
# Mismatched elements: 1 / 3 (33.3%)
# Max absolute difference: 9.e-09
# Max relative difference: 7.29000059e-08
#  x: array([0.      , 0.123457,      nan])
#  y: array([0.      , 0.123457,      nan])

# %%
# 数组排序
# 两个数组必须形状一致并且第一个数组的元素严格小于第二个数组的元素，
# 否则assert_ array_less函数将抛出异常
print(np.testing.assert_array_less([0, 0.123456789, np.nan], [1, 0.23456780, 
np.nan]))
print(np.testing.assert_array_less([0, 0.123456789, np.nan], [0, 0.123456780, 
np.nan]))
# Out:
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-067d7e97f38b> in <module>
#       4 print(np.testing.assert_array_less([0, 0.123456789, np.nan], [1, 0.23456780,
#       5 np.nan]))
# ----> 6 print(np.testing.assert_array_less([0, 0.123456789, np.nan], [0, 0.123456780,
#       7 np.nan]))
#
#     [... skipping hidden 1 frame]
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_array_compare(comparison, x, y, err_msg, verbose, header, precision, equal_nan, equal_inf)
#     840                                 verbose=verbose, header=header,
#     841                                 names=('x', 'y'), precision=precision)
# --> 842             raise AssertionError(msg)
#     843     except ValueError:
#     844         import traceback
#
# AssertionError:
# Arrays are not less-ordered
#
# Mismatched elements: 2 / 3 (66.7%)
# Max absolute difference: 9.e-09
# Max relative difference: 7.29000059e-08
#  x: array([0.      , 0.123457,      nan])
#  y: array([0.      , 0.123457,      nan])

# %%
# 对象比较
# 假设你需要比较两个元组。我们可以用assert_equal函数来完成。
print(np.testing.assert_equal((1, 2), (1, 3)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-b0f754badd9a> in <module>
#       1 # 对象比较
#       2 # 假设你需要比较两个元组。我们可以用assert_equal函数来完成。
# ----> 3 print(np.testing.assert_equal((1, 2), (1, 3)))
#
#     [... skipping hidden 1 frame]
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_equal(actual, desired, err_msg, verbose)
#     421         # Explicitly use __eq__ for comparison, gh-2552
#     422         if not (desired == actual):
# --> 423             raise AssertionError(msg)
#     424
#     425     except (DeprecationWarning, FutureWarning) as e:
#
# AssertionError:
# Items are not equal:
# item=1
#
#  ACTUAL: 2
#  DESIRED: 3

# %%
# 字符串比较
print(np.testing.assert_string_equal("NumPy", "NumPy") )
print(np.testing.assert_string_equal("NumPy", "Numpy"))
# Out:
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-f4459869630d> in <module>
#       1 # 字符串比较
#       2 print(np.testing.assert_string_equal("NumPy", "NumPy") )
# ----> 3 print(np.testing.assert_string_equal("NumPy", "Numpy"))
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_string_equal(actual, desired)
#    1202     msg = f"Differences in strings:\n{''.join(diff_list).rstrip()}"
#    1203     if actual != desired:
# -> 1204         raise AssertionError(msg)
#    1205
#    1206
#
# AssertionError: Differences in strings:
# - NumPy?    ^
# + Numpy?    ^

# %%
# 浮点数比较
# NumPy中的assert_array_almost_equal_nulp和assert_array_max_ulp函数
# 可以提供可靠的浮点数比较功能。
eps = np.finfo(float).eps
print(eps)
print(np.testing.assert_array_almost_equal_nulp(1.0, 1.0 + eps))
print(np.testing.assert_array_almost_equal_nulp(1.0, 1.0 + 2 * eps))
# Out:
# 2.220446049250313e-16
# None
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-7db77edee480> in <module>
#       5 print(eps)
#       6 print(np.testing.assert_array_almost_equal_nulp(1.0, 1.0 + eps))
# ----> 7 print(np.testing.assert_array_almost_equal_nulp(1.0, 1.0 + 2 * eps))
#
# F:\Anaconda3\lib\site-packages\numpy\testing\_private\utils.py in assert_array_almost_equal_nulp(x, y, nulp)
#    1590             max_nulp = np.max(nulp_diff(x, y))
#    1591             msg = "X and Y are not equal to %d ULP (max is %g)" % (nulp, max_nulp)
# -> 1592         raise AssertionError(msg)
#    1593
#    1594
#
# AssertionError: X and Y are not equal to 1 ULP (max is 2)

# %%
# 多 ULP 的浮点数比较
# assert_array_max_ulp函数可以指定ULP的数量作为允许的误差上界。
# 参数maxulp接受整数作为ULP数量的上限，默认值为1。
print(np.testing.assert_array_max_ulp(1.0, 1.0 + eps))
print(np.testing.assert_array_max_ulp(1.0, 1 + 2 * eps, maxulp=2))
# Out:
# [1.]
# [2.]

# %%
def factorial(n): 
    if n == 0: 
        return 1 
    if n < 0: 
        print("Unv") 
    return np.arange(1, n+1).cumprod()

factorial(3)
# Out:
# array([1, 2, 6], dtype=int32)
